# %% [markdown]
# ---------------------
#                               💻 || ⭐ Instituto de Computação - Programa de Pós Graduação do Instituto de Computação ⭐ || 💻
# --------------------
#
# ---------------------
#                               💻 || ♥ Disciplina: Processamento de Imagem - Aluna: Janaine Ferreira dos Santos ♥ || 💻
# --------------------

# %% [markdown]
# # Create Images
#
#
#
#
# *Atenção: Utilize numpy.linspace() e numpy.meshgrid() para gerar as imagens.*
#
# 1. Crie a imagem de um parabolóide com um eixo dimensionado (como um parabolóide oval)

# %%
# !pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define os parâmetros para o parabolóide
a = 1.0  # Fator de escala para o eixo x
b = 0.5  # Fator de escala para o eixo y

# Cria uma grade de pontos usando numpy.linspace
x = np.linspace(-7, 7, 100)
y = np.linspace(-7, 7, 100)
X, Y = np.meshgrid(x, y)

# Calcula os valores de z para o parabolóide
Z = a * X**2 + b * Y**2

# Cria um gráfico 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')

# Define os rótulos dos eixos
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Define o título do gráfico
plt.title('Parabolóide com Eixos Dimensionados')

# Mostra o gráfico
plt.show()

# %% [markdown]
# 2. Crie a imagem de um pecado girado usando rotação de coordenadas.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define os parâmetros para o seno girado
frequencia = 2.0  # Frequência do seno
angulo_rotacao = np.pi / 4  # Ângulo de rotação (45 graus)

# Cria uma grade de pontos usando numpy.linspace
x = np.linspace(0, 10, 1000)

# Calcula os valores de y para o seno
y = np.sin(2 * np.pi * frequencia * x)

# Aplica a rotação de coordenadas
x_rotacionado = x * np.cos(angulo_rotacao) - y * np.sin(angulo_rotacao)
y_rotacionado = x * np.sin(angulo_rotacao) + y * np.cos(angulo_rotacao)

# Plota o seno girado
plt.figure(figsize=(8, 4))
plt.plot(x_rotacionado, y_rotacionado, label='Seno Girado')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Seno Girado com Rotação de Coordenadas')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 3. Crie a imagem de um gaussiano

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define os parâmetros para a Distribuição Gaussiana
media = 0.0
desvio_padrao = 1.0

# Cria uma grade de pontos usando numpy.linspace
x = np.linspace(-5, 5, 1000)

# Calcula os valores da função de densidade de probabilidade (PDF) da Gaussiana
pdf = (1 / (desvio_padrao * np.sqrt(2 * np.pi))) * np.exp(-(x - media)**2 / (2 * desvio_padrao**2))

# Plota a Distribuição Gaussiana
plt.figure(figsize=(8, 4))
plt.plot(x, pdf, label='Distribuição Gaussiana')
plt.xlabel('X')
plt.ylabel('PDF')
plt.title('Distribuição Gaussiana com numpy.linspace()')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define os parâmetros para a Distribuição Gaussiana
media = 0.0
desvio_padrao = 1.0

# Cria uma grade de pontos usando numpy.meshgrid
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# Calcula os valores da função de densidade de probabilidade (PDF) da Gaussiana
pdf = (1 / (desvio_padrao * np.sqrt(2 * np.pi))) * np.exp(-(X - media)**2 / (2 * desvio_padrao**2))

# Plota a Distribuição Gaussiana
plt.figure(figsize=(8, 4))
plt.contourf(X, Y, pdf, cmap='viridis')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Distribuição Gaussiana com numpy.meshgrid()')
plt.colorbar(label='PDF')
plt.grid(True)
plt.show()

# %% [markdown]
# 4. Crie uma função que gere a imagem de uma Gaussiana opcionalmente rotacionada por um ângulo \theta e com mx, my, sx, sy como argumentos de entrada.

# %%
import numpy as np
import matplotlib.pyplot as plt

def rot_gaussiana(mx, my, sx, sy, theta=0):
    """
    Gera uma imagem de uma distribuição gaussiana girada.

    Argumentos:
        mx (float): média ao longo do eixo x.
        my (float): Média ao longo do eixo y.
        sx (float): Desvio padrão ao longo do eixo x.
        sy (float): Desvio padrão ao longo do eixo y.
        theta (float, opcional): Ângulo de rotação em radianos (o padrão é 0).

    Retorna:
        Nenhum (exibe o gráfico).
    """
    # Cria uma grade de pontos usando numpy.meshgrid
    x = np.linspace(-7, 7, 100)
    y = np.linspace(-7, 7, 100)
    X, Y = np.meshgrid(x, y)

    # Calcula os valores da distribuição gaussiana
    Z = (1 / (2 * np.pi * sx * sy)) * np.exp(
        -((X - mx) ** 2 / (2 * sx ** 2) + (Y - my) ** 2 / (2 * sy ** 2))
    )

    # Aplica a rotação às coordenadas
    X_rotacao = X * np.cos(theta) - Y * np.sin(theta)
    Y_rotacao = X * np.sin(theta) + Y * np.cos(theta)

    # Plot da rotação gaussiana
    plt.figure(figsize=(8, 4))
    plt.contourf(X_rotacao, Y_rotacao, Z, cmap='viridis')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title(f'Rootação Gaussiana (θ = {np.degrees(theta):.2f}°)')
    plt.colorbar(label='PDF')
    plt.grid(True)
    plt.show()

# Exemplo
rot_gaussiana(mx=0, my=0, sx=1, sy=0.5, theta=np.pi / 4)
